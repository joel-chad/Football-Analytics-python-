# %%
import pandas as pd

df = pd.read_html("https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats", header=1)
df[10].head()
# Out:
#            Player   Nation    Pos     Age  MP    Min  Mn/MP  Min%  90s  \
# 0    João Cancelo   pt POR     DF  27-159  10  887.0   89.0  98.6  9.9
# 1      Rúben Dias   pt POR     DF  24-172  10  829.0   83.0  92.1  9.2
# 2         Ederson   br BRA     GK  28-077   9  810.0   90.0  90.0  9.0
# 3  Bernardo Silva   pt POR     MF  27-084   9  757.0   84.0  84.1  8.4
# 4   Jack Grealish  eng ENG  FW,MF  26-053   9  738.0   82.0  82.0  8.2
#
#    Starts  ...  onGA   +/-  +/-90  On-Off  onxG  onxGA  xG+/-  xG+/-90  \
# 0      10  ...   5.0  15.0   1.52    8.45  21.8    7.1   14.7     1.49
# 1       9  ...   6.0  12.0   1.30   -1.23  20.1    6.8   13.2     1.44
# 2       9  ...   6.0  12.0   1.33   -0.67  20.0    6.4   13.7     1.52
# 3       9  ...   5.0  14.0   1.66    1.66  17.9    5.9   12.0     1.42
# 4       9  ...   3.0  11.0   1.34   -0.33  17.9    4.7   13.2     1.62
#
#    On-Off.1  Matches
# 0      2.60  Matches
# 1     -0.16  Matches
# 2      0.66  Matches
# ...
