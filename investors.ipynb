# %%
import pandas as pd

# %%
df = pd.read_csv("investors.csv")
df
# Out:
#      Investor Number     First Name Last Name                    Email  \
# 0             string           Test    string                   string
# 1             string           test    string                   string
# 2                NaN        Rishny     Zeline   r-zeline@hotmail.co.uk
# 3                NaN       Primrose     Ndava      primndava@yahoo.com
# 4                NaN       Nhlanhla    Kutiwa    nhlax2001@yahoo.co.uk
# ...              ...            ...       ...                      ...
# 1746               0         Albert    Gotora   albertgotora@gmail.com
# 1747               0  Bekezela Anne    Marime     bekemarime@gmail.com
# 1748             NaN       Bekezela    Marime     bekemarime@gmail.com
# 1749             NaN         Sample      Test       sample@example.com
# 1750             NaN          Robby   Malunga  malungarobbie@gmail.com
#
#          ID Number      Contact Registration Date     Action
# ...

# %%
df['First Name'] = df["First Name"].str.rpartition(' ')[0]

# %%
df
# Out:
#      Investor Number First Name Last Name                    Email  \
# 0             string               string                   string
# 1             string               string                   string
# 2                NaN     Rishny    Zeline   r-zeline@hotmail.co.uk
# 3                NaN                Ndava      primndava@yahoo.com
# 4                NaN               Kutiwa    nhlax2001@yahoo.co.uk
# ...              ...        ...       ...                      ...
# 1746               0               Gotora   albertgotora@gmail.com
# 1747               0   Bekezela    Marime     bekemarime@gmail.com
# 1748             NaN               Marime     bekemarime@gmail.com
# 1749             NaN                 Test       sample@example.com
# 1750             NaN              Malunga  malungarobbie@gmail.com
#
#          ID Number      Contact Registration Date     Action
# 0           string       string          6/9/2022  undefined
# ...

# %%
df.to_csv('Investors1.csv', encoding='utf-8', index=False)

# %%
df['Last Name'] = df["Last Name"].split(' ')[-1]
